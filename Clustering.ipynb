# ...

# %%
"""
side info:

            typical car speed : 13 - 30 m/s
            
            

"""
# Out:
# '\nside info:\n\n            typical car speed : 13 - 30 m/s\n            \n            \n\n'

# %%
def quantize_speeds(dataframe):
    """
    quantizes speeds for given dataframe to reduce computation

    returns: quantized dataframe
    """
    output_dataframe = pd.DataFrame()
    
    cols = dataframe.columns
    
    for col in cols:
        output_dataframe[col] = dataframe[col].round(decimals=3)
    
    return output_dataframe

# %%
def get_positions(dataframe):
    """
    calculates positions for each vehicle for the trip

    returns: positions dataframe
    """
    output_dataframe = pd.DataFrame()
    
    cols = dataframe.columns
    
    for col in cols:
        output_dataframe[col] = dataframe[col].cumsum()
    
    return output_dataframe

# %%
quantized_df = quantize_speeds(df)

# %%
quantized_df
# Out:
#     vehicle_1  vehicle_2  vehicle_3  vehicle_4  vehicle_5  vehicle_6  \
# 0      10.468      7.401     11.090     10.470      9.361      5.692
# 1      10.824      8.080     11.408     11.020      9.724      6.197
# 2      13.272      9.222     14.100     13.224     11.863      7.107
# 3      13.218      9.368     14.008     13.247     11.835      7.212
# 4      12.761      9.239     13.486     12.864     11.438      7.099
# 5      10.946      8.525     11.500     11.299      9.859      6.515
# 6      12.580      9.092     13.296     12.670     11.272      6.984
# 7      10.678      8.483     11.212     11.109      9.637      6.478
# 8       9.874      8.110     10.361     10.406      8.938      6.180
# 9       9.833      8.040     10.321     10.349      8.900      6.131
# 10     13.193      9.400     13.969     13.236     11.813      7.231
# 11     13.778      9.580     14.639     13.734     12.320      7.385
# 12     12.540      9.063     13.256     12.638     11.240      6.967
# ...

# %%
positions_df = get_positions(quantized_df)

# %%
positions_df
# Out:
#     vehicle_1  vehicle_2  vehicle_3  vehicle_4  vehicle_5  vehicle_6  \
# 0      10.468      7.401     11.090     10.470      9.361      5.692
# 1      21.292     15.481     22.498     21.490     19.085     11.889
# 2      34.564     24.703     36.598     34.714     30.948     18.996
# 3      47.782     34.071     50.606     47.961     42.783     26.208
# 4      60.543     43.310     64.092     60.825     54.221     33.307
# 5      71.489     51.835     75.592     72.124     64.080     39.822
# 6      84.069     60.927     88.888     84.794     75.352     46.806
# 7      94.747     69.410    100.100     95.903     84.989     53.284
# 8     104.621     77.520    110.461    106.309     93.927     59.464
# 9     114.454     85.560    120.782    116.658    102.827     65.595
# 10    127.647     94.960    134.751    129.894    114.640     72.826
# 11    141.425    104.540    149.390    143.628    126.960     80.211
# 12    153.965    113.603    162.646    156.266    138.200     87.178
# ...

# %%
pos_timestep_current = []
pos_cluster = []


def cluster(dataframe, test_car ,timestep_start, timestep_end):
#     test_vehicle = 'vehicle_1'
    
#     position_test_start = dataframe[test_car][timestep_start] #test vehicle postion for starting timestep
    position_test_end = dataframe[test_car][timestep_end] #test vehicle postion for ending timestep
    
        
#     all_pos_timestep_start = dataframe.iloc[timestep_start,:] #postions data for all other cars for starting timestep
    all_pos_timestep_end = dataframe.iloc[timestep_end,1:] #postions data for all other cars for ending timestep
        
#     for j in range(len(all_pos_timestep_start)):
        
#         if (abs(all_pos_timestep_start[j]-position_test_start)) < 3:
#             print(all_pos_timestep_start[j] )
#             print(position_test_start)
#             pos_cluster.append(j)
#             print(pos_cluster)
            
    for j in range(len(all_pos_timestep_end)):

        if (abs(all_pos_timestep_end[j]-position_test_end)) < 50:
            print(all_pos_timestep_end[j] )
            print(position_test_end)
            pos_cluster.append(j)
            print(pos_cluster)


cluster(fab_data,'vehicle_2',1, 10)

    
#     """
#     clustering algorithm for offloading decision making

#     returns: optimal cluster formation for given service vehicle
#     """        
#     ...
# Out:
# 189.92000000000002
# 189.92000000000002
# [0]
# 229.28000000000003
# 189.92000000000002
# [0, 3]
# 145.652
# 189.92000000000002
# [0, 3, 4]
# 231.414
# 189.92000000000002
# [0, 3, 4, 5]
# 232.08399999999997
# 189.92000000000002
# [0, 3, 4, 5, 11]
# 206.78600000000003
# 189.92000000000002
# [0, 3, 4, 5, 11, 13]
# 232.59
# 189.92000000000002
# [0, 3, 4, 5, 11, 13, 15]
# 175.926
# 189.92000000000002
# [0, 3, 4, 5, 11, 13, 15, 17]

# %%
pos_cluster
# Out:
# [0, 3, 4, 5, 11, 13, 15, 17]

# %%
plt.scatter([x for x in range(1,21) ],positions_df.iloc[0,:])

# %%
# starting position of all cars
plt.figure(figsize=(8, 6), dpi=100)
plt.scatter(positions_df.iloc[0,:],[x for x in range(1,21) ])
plt.scatter(positions_df.iloc[10,:],[x for x in range(1,21) ])
# plt.fig()

# %%
fab_data=positions_df.copy()

# %%
fab_data=fab_data*2

# %%
fab_data
# Out:
#     vehicle_1  vehicle_2  vehicle_3  vehicle_4  vehicle_5  vehicle_6  \
# 0      20.936     14.802     22.180     20.940     18.722     11.384
# 1      42.584     30.962     44.996     42.980     38.170     23.778
# 2      69.128     49.406     73.196     69.428     61.896     37.992
# 3      95.564     68.142    101.212     95.922     85.566     52.416
# 4     121.086     86.620    128.184    121.650    108.442     66.614
# 5     142.978    103.670    151.184    144.248    128.160     79.644
# 6     168.138    121.854    177.776    169.588    150.704     93.612
# 7     189.494    138.820    200.200    191.806    169.978    106.568
# 8     209.242    155.040    220.922    212.618    187.854    118.928
# 9     228.908    171.120    241.564    233.316    205.654    131.190
# 10    255.294    189.920    269.502    259.788    229.280    145.652
# 11    282.850    209.080    298.780    287.256    253.920    160.422
# 12    307.930    227.206    325.292    312.532    276.400    174.356
# ...

# %%
pos_timestep_current = []
pos_cluster = []


def cluster(dataframe, test_car, timestep, cluster_radius):
    
    position_test = dataframe[test_car][timestep] #test vehicle postion for ending timestep
    
    all_pos_timestep = dataframe.iloc[timestep,1:] #postions data for all other cars for ending timestep

    for j in range(len(all_pos_timestep)):

        if (abs(all_pos_timestep[j]-position_test)) < cluster_radius:

            pos_cluster.append(j)
    print(pos_cluster)

cluster(fab_data,'vehicle_2', 10,50)
# Out:
# [0, 3, 4, 5, 11, 13, 15, 17]

# %%
pos_timestep_current = []
pos_cluster = []


def cluster(dataframe, test_car, timestep, cluster_radius):
    
    position_test = dataframe[test_car][timestep] #test vehicle postion for ending timestep
    
    all_pos_timestep = dataframe.iloc[timestep,1:] #postions data for all other cars for ending timestep

    for j in range(len(all_pos_timestep)):

        if (abs(all_pos_timestep[j]-position_test)) < cluster_radius:

            pos_cluster.append(j)
    print(pos_cluster)

cluster(fab_data,'vehicle_2', 10,70)
# Out:
# [0, 2, 3, 4, 5, 9, 11, 12, 13, 14, 15, 16, 17]

# %%
'''
As in 50 meter radius cluster for vehicle_2(test_vehicle) clustering algorithm shows 8 service vehicle 

but for cluster radius of 70 meter algo shows 13 service vehicle

'''
# Out:
# '\nAs in 50 meter radius cluster for vehicle_2(test_vehicle) clustering algorithm shows 8 service vehicle \n\nbut for cluster radius of 70 meter algo shows 13 service vehicle\n\n'
